# %% [markdown]
# # Time series data = 시계열 데이터

# %%
import numpy as np
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('./avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
df.groupby('type').mean()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume           4046  \
# type
# conventional   24.236686      1.158040  1.653213e+06  578611.649925
# organic        24.227776      1.653999  4.781121e+04    7311.281600
#
#                        4225          4770     Total Bags     Small Bags  \
# type
# conventional  574805.318859  45405.796798  454390.130901  346721.795885
# organic        15411.857724    266.254582   24817.654696   17613.474543
#
#                  Large Bags  XLarge Bags         year
# type
# conventional  101457.698855  6210.635065  2016.147929
# organic         7202.982659     1.197164  2016.147868

# %%
df = df.loc[(df.type == 'conventional') & (df.region == 'TotalUS')]
df['Date'] = pd.to_datetime(df['Date'])
data = df[['Date', 'AveragePrice']].reset_index(drop=True)
data = data.rename(columns = {'Date':'ds', 'AveragePrice': 'y'})
data.head()
# Out:
#           ds     y
# 0 2015-12-27  0.95
# 1 2015-12-20  0.98
# 2 2015-12-13  0.93
# 3 2015-12-06  0.89
# 4 2015-11-29  0.99

# %%
data.plot(x='ds', y='y', figsize = (16,8))

# %%
model = Prophet()
model.fit(data)
future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)
forecast.tail()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 529 2019-03-21  1.171972    0.980244    1.243176     1.111761     1.239786
# 530 2019-03-22  1.171861    0.990485    1.251578     1.111368     1.239896
# 531 2019-03-23  1.171750    0.980810    1.245638     1.110721     1.239925
# 532 2019-03-24  1.171640    0.987917    1.244037     1.110075     1.240108
# 533 2019-03-25  1.171529    1.000897    1.245918     1.109429     1.240173
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 529       -0.059338             -0.059338             -0.059338 -0.059338
# 530       -0.057928             -0.057928             -0.057928 -0.057928
# 531       -0.056045             -0.056045             -0.056045 -0.056045
# 532       -0.053704             -0.053704             -0.053704 -0.053704
# 533       -0.050936             -0.050936             -0.050936 -0.050936
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 529     -0.059338     -0.059338                   0.0
# 530     -0.057928     -0.057928                   0.0
# 531     -0.056045     -0.056045                   0.0
# 532     -0.053704     -0.053704                   0.0
# 533     -0.050936     -0.050936                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 529                         0.0                         0.0  1.112634
# 530                         0.0                         0.0  1.113933
# 531                         0.0                         0.0  1.115706
# 532                         0.0                         0.0  1.117936
# 533                         0.0                         0.0  1.120593

# %%
model = Prophet()
model.fit(data)
future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)
forecast.tail()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 529 2019-03-21  1.171972    0.980468    1.232066     1.093522     1.235739
# 530 2019-03-22  1.171861    0.980830    1.234299     1.093153     1.235995
# 531 2019-03-23  1.171750    0.983347    1.236650     1.092784     1.236259
# 532 2019-03-24  1.171640    0.986796    1.250238     1.092353     1.236547
# 533 2019-03-25  1.171529    0.994855    1.244548     1.091992     1.236835
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 529       -0.059338             -0.059338             -0.059338 -0.059338
# 530       -0.057928             -0.057928             -0.057928 -0.057928
# 531       -0.056045             -0.056045             -0.056045 -0.056045
# 532       -0.053704             -0.053704             -0.053704 -0.053704
# 533       -0.050936             -0.050936             -0.050936 -0.050936
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 529     -0.059338     -0.059338                   0.0
# 530     -0.057928     -0.057928                   0.0
# 531     -0.056045     -0.056045                   0.0
# 532     -0.053704     -0.053704                   0.0
# 533     -0.050936     -0.050936                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 529                         0.0                         0.0  1.112634
# 530                         0.0                         0.0  1.113933
# 531                         0.0                         0.0  1.115706
# 532                         0.0                         0.0  1.117936
# 533                         0.0                         0.0  1.120593

# %%
fig1 = model.plot(forecast)

# %%
fig2 = model.plot_components(forecast)
