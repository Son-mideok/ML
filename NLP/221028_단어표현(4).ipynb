# %% [markdown]
# ## Bag of Words(BoW)

# %% [markdown]
# ### Basic

# %%
from konlpy.tag import Okt

okt = Okt()

def build_bag_of_words(document):
    document = document.replace('.', '')
    tokenized_document = okt.morphs(document)
    
    word_to_index = {}
    bow = []
    
    for word in tokenized_document:        
        if word not in word_to_index.keys():  # 단어가 처음 나왔을 경우
            word_to_index[word] = len(word_to_index)  
            bow.insert(len(word_to_index) - 1, 1)
        else:                                 # 단어가 다시 나왔을 경우
            index = word_to_index.get(word)
            print(word, type(word_to_index))
            bow[index] = bow[index] + 1
                    
    return word_to_index, bow
    
    
doc1 = "정부가 발표하는 물가상승률과 소비자가 느끼는 물가상승률은 다르다."
vocab, bow = build_bag_of_words(doc1)
print('vocabulary :', vocab)
print('bag of words vector :', bow)
# Out:
# 가 <class 'dict'>
# 물가상승률 <class 'dict'>
# vocabulary : {'정부': 0, '가': 1, '발표': 2, '하는': 3, '물가상승률': 4, '과': 5, '소비자': 6, '느끼는': 7, '은': 8, '다르다': 9}
# bag of words vector : [1, 2, 1, 1, 2, 1, 1, 1, 1, 1]

# %%
doc2 = '소비자는 주로 소비하는 상품을 기준으로 물가상승률을 느낀다.'

vocab, bow = build_bag_of_words(doc2)
print('vocabulary :', vocab)
print('bag of words vector :', bow)
# Out:
# 을 <class 'dict'>
# vocabulary : {'소비자': 0, '는': 1, '주로': 2, '소비': 3, '하는': 4, '상품': 5, '을': 6, '기준': 7, '으로': 8, '물가상승률': 9, '느낀다': 10}
# bag of words vector : [1, 1, 1, 1, 1, 1, 2, 1, 1, 1, 1]

# %%
doc3 = doc1 + ' ' + doc2
vocab, bow = build_bag_of_words(doc3)

print('vocabulary :', vocab)
print('bag of words vector :', bow)
# Out:
# 가 <class 'dict'>
# 물가상승률 <class 'dict'>
# 소비자 <class 'dict'>
# 하는 <class 'dict'>
# 물가상승률 <class 'dict'>
# 을 <class 'dict'>
# vocabulary : {'정부': 0, '가': 1, '발표': 2, '하는': 3, '물가상승률': 4, '과': 5, '소비자': 6, '느끼는': 7, '은': 8, '다르다': 9, '는': 10, '주로': 11, '소비': 12, '상품': 13, '을': 14, '기준': 15, '으로': 16, '느낀다': 17}
# bag of words vector : [1, 2, 1, 2, 3, 1, 2, 1, 1, 1, 1, 1, 1, 1, 2, 1, 1, 1]

# %% [markdown]
# ### BOW-CountVectorizer

# %%
# CountVectorizer : 띄어쓰기만으로 토큰화 진행
from sklearn.feature_extraction.text import CountVectorizer

corpus = ['you know I want your love. because I love you.']
vector = CountVectorizer()

# 빈도수 기록
print('bag of words vector :', vector.fit_transform(corpus).toarray()) 

# 단어의 인덱스
print('vocabulary :',vector.vocabulary_)
# Out:
# bag of words vector : [[1 1 2 1 2 1]]
# vocabulary : {'you': 4, 'know': 1, 'want': 3, 'your': 5, 'love': 2, 'because': 0}

# %% [markdown]
# ### BOW-불용어 제거(사용자 정의 불용어)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# %%
# 사용자정의 불용어 적용
text = ["Family is not an important thing. It's everything."]
vect = CountVectorizer(stop_words=["the", "a", "an", "is", "not"])

print('bag of words vector :',vect.fit_transform(text).toarray())
print('vocabulary :',vect.vocabulary_)
# Out:
# bag of words vector : [[1 1 1 1 1]]
# vocabulary : {'family': 1, 'important': 2, 'thing': 4, 'it': 3, 'everything': 0}

# %% [markdown]
# ### BOW-불용어 제거(CountVectorizer 포함된 불용어)

# %%
text = ["Family is not an important thing. It's everything."]
vect = CountVectorizer(stop_words="english")

print('bag of words vector :',vect.fit_transform(text).toarray())
print('vocabulary :',vect.vocabulary_)
# Out:
# bag of words vector : [[1 1 1]]
# vocabulary : {'family': 0, 'important': 1, 'thing': 2}

# %% [markdown]
# ### BOW-불용어 제거(NLTK 포함된 불용어)

# %%
text = ["Family is not an important thing. It's everything."]
stop_words = stopwords.words("english")

vect = CountVectorizer(stop_words=stop_words)
print('bag of words vector :',vect.fit_transform(text).toarray()) 
print('vocabulary :',vect.vocabulary_)
# Out:
# bag of words vector : [[1 1 1 1]]
# vocabulary : {'family': 1, 'important': 2, 'thing': 3, 'everything': 0}

# %% [markdown]
# ## 문서 단어 행렬(Document-Term Matrix, DTM)

# %% [markdown]
# ### 데이터 다운로드

# %%
# colab : wget -c https://raw.githubusercontent.com/euphoris/datasets/master/imdb.xlsx

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\82102\anaconda3\lib\site-packages (3.2)

# %%
# windows일 경우
import wget

wget.download('https://raw.githubusercontent.com/euphoris/datasets/master/imdb.xlsx')
# Out:
# 100% [..............................................................................] 55772 / 55772
# 'imdb (4).xlsx'

# %% [markdown]
# ### 데이터 열기

# %%
import pandas as pd

df = pd.read_excel('imdb.xlsx', index_col=0)

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
df.shape
# Out:
# (748, 2)

# %% [markdown]
# ### TDM 만들기

# %%
from sklearn.feature_extraction.text import CountVectorizer

# max_features : 빈도순으로 최대 500단어까지 포함
# stop_words='english' : 불용어(관사, 전치사등을 제거)
cv = CountVectorizer(max_features=500, stop_words='english')

# %%
tdm = cv.fit_transform(df['review'])
tdm
# Out:
# <748x500 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3434 stored elements in Compressed Sparse Row format>

# %%
tdm.shape
# Out:
# (748, 500)

# %% [markdown]
# ### 단어 목록

# %%
# 단어 목록을 볼때는 tdm이 아니라 cv에 저장되어 있음
cv.get_feature_names()[:10]
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['10',
#  '20',
#  '90',
#  'absolutely',
#  'acted',
#  'acting',
#  'action',
#  'actor',
#  'actors',
#  'actress']

# %%
len(cv.get_feature_names())
# Out:
# 500

# %% [markdown]
# ### 단어별 총 빈도

# %%
tdm.sum(axis=0) # 열별 단어 수
# Out:
# matrix([[ 29,   3,   6,   9,   3,  43,   7,  10,  19,   3,   3,  10,   3,
#            4,   3,   4,   9,   3,   3,   3,   6,   3,   4,   3,  13,   4,
#            3,   5,   3,   8,   5,   3,  14,  71,   4,  11,   4,   6,   8,
#           25,  18,  10,   5,  10,   4,   3,   4,  10,   3,   3,   6,   7,
#            3,   4,  10,   5,   3,  18,   6,   8,  24,  35,   4,   3,   7,
#            3,   4,   5,   8,  10,   6,   5,   5,   7,   4,   3,   3,   5,
#            3,   3,   4,   4,   7,   4,   5,   3,   4,   6,   4,   3,   5,
#            4,   3,   5,   4,   3,   9,   3,   4,   3,  13,  11,  22,   5,
#            3,   9,   5,  12,   6,   3,   9,  12,  26,   4,  10,   3,   3,
#            3,   3,   4,   4,   3,   6,   3,   9,  11,  11,   4,   5,   3,
#            9,   4,   6,   3,   8,   3,   3,  16,   4,   7,   4,   4,   5,
#            8,   5,   7,   5,   7,   5,   3,   3,  10,   5, 163,  24,   3,
#            3,   5,   6,   4,   5,  19,   3,   9,   3,   7,   5,   3,   4,
#            3,   6,   3,   7,   3,   6,   4,   4,  10,  58,   8,   3,   3,
#           41,   3,   5,   6,   3,   3,   4,   3,   6,   3,   3,  10,   6,
#            3,   6,   6,   6,   4,   6,   9,   5,   4,   3,   4,   6,   3,
#            4,   4,   3,   3,   6,   3,   3,   4,   4,   4,  12,   5,   4,
#            9,   7,   3,   5,  63,   8,   8,   3,  14,   6,   5,   3,   5,
#            3,   3,   5,   4,  12,  48,  10,  12,   7,   3,  17,   4,   7,
#            3,   8,  19,   4,   3,   3,   4,   9,   3,  22,  10,   4,   5,
#            3,  22,   8,   6,  13,   3,   3,   4,   3,   4,   4,   3,   4,
#            6,   3,   5,   8,   4,   5,   4,   8,   3,   3,   6, 182,  29,
#            4,  14,   3,   3,   5,   6,   5,   5,   3,   3,   3,   4,   5,
#            8,   4,   3,   5,   3,   5,   4,   5,  14,   6,  12,   6,   5,
#            4,  10,   4,   4,   9,  10,   7,  28,   4,   6,   6,   3,   3,
#           10,   4,   3,   4,  13,   8,   4,   3,   5,   3,   3,   3,   3,
#           10,   3,   3,   3,   3,   4,   4,  21,  41,  13,   6,   3,   3,
#            3,   6,   4,   5,  13,   4,   4,   3,   5,  12,  13,   3,   4,
#           14,  19,   3,  14,   3,  24,   3,   6,   7,  23,   7,   3,   8,
#            3,   3,   4,  11,   5,   5,  10,   5,   6,   4,   5,   4,   4,
#            6,   4,   3,   3,   3,   9,   3,   3,   3,   3,   4,   3,   5,
#            3,   4,  28,   4,   5,   3,  14,   6,   3,   7,   7,   8,   3,
#            5,   3,   3,   8,   4,   3,   5,   4,  12,   5,   4,   3,  13,
#           12,  21,   3,   3,  12,   5,   3,  43,   5,   4,   3,   5,   4,
#           15,   3,   4,   3,   4,   9,   4,   4,   3,   8,   3,   4,   3,
#            9,   4,   4,   6,   8,   4,   4,   3,  13,   4,   6,   3,   7,
#           14,   7,  17,   3,   9,  22,  23,   8,   3,   3,   3,   3,   5,
#           18,   3,   5,  20,   5,   6,  11,  11,  13,   3,   3,   3,  13,
#            7,   3,   5,  14,   3,   4]], dtype=int64)

# %%
tdm.sum(axis=1) # 행별 단어 수
# Out:
# matrix([[  5],
#         [  5],
#         [ 12],
#         [  3],
#         [  6],
#         [  7],
#         [  2],
#         [  7],
#         [  2],
#         [  2],
#         [  1],
#         [  4],
#         [  3],
#         [  1],
#         [  5],
#         [  5],
#         [  6],
#         [ 10],
#         [  3],
#         [229],
#         [  5],
#         [  2],
#         [  5],
#         [  3],
#         [  1],
#         [  2],
#         [  4],
#         [  2],
#         [  7],
#         [  3],
#         [  1],
#         [  0],
#         [  1],
#         [  3],
#         [  4],
#         [  6],
#         [  3],
#         [  6],
#         [ 11],
#         [  3],
#         [  4],
#         [  3],
#         [  2],
#         [  0],
#         [  0],
#         [  6],
#         [  4],
#         [  3],
#         [  1],
#         [  8],
#         [  5],
#         [  5],
#         [  2],
#         [  2],
#         [  4],
#         [  5],
#         [  5],
#         [  1],
#         [  2],
#         [  4],
#         [  3],
#         [  4],
#         [  0],
#         [  1],
#         [  2],
#         [  3],
#         [  5],
#         [  2],
#         [  6],
#         [  5],
#         [  5],
#         [  3],
#         [  1],
#         [  3],
#         [  2],
#         [  2],
#         [  4],
#         [  3],
#         [  7],
#         [  3],
#         [  5],
#         [  6],
#         [  2],
#         [  4],
#         [  8],
#         [  2],
#         [  4],
#         [  4],
#         [  3],
#         [  0],
#         [  2],
#         [  1],
#         [  1],
#         [  1],
#         [  1],
#         [  5],
#         [  2],
#         [  2],
#         [  3],
#         [  2],
#         [  1],
#         [  1],
#         [  4],
#         [  3],
#         [  3],
#         [  8],
#         [  4],
#         [  5],
#         [  2],
#         [  6],
#         [  3],
#         [  4],
#         [  3],
#         [  2],
#         [  0],
#         [  3],
#         [  2],
#         [  2],
#         [  2],
#         [  2],
#         [  3],
#         [  3],
#         [  1],
#         [  1],
#         [  1],
#         [  3],
#         [  2],
#         [  1],
#         [  2],
#         [  5],
#         [  6],
#         [  3],
#         [  1],
#         [  4],
#         [  4],
#         [ 65],
#         [371],
#         [ 16],
#         [  3],
#         [  3],
#         [  2],
#         [  2],
#         [  2],
#         [  0],
#         [  5],
#         [  3],
#         [  3],
#         [  2],
#         [  2],
#         [ 78],
#         [  2],
#         [  4],
#         [  2],
#         [  5],
#         [  0],
#         [  2],
#         [  6],
#         [  2],
#         [  3],
#         [  8],
#         [  8],
#         [  5],
#         [  3],
#         [  3],
#         [  3],
#         [  3],
#         [  5],
#         [  1],
#         [  5],
#         [  3],
#         [  4],
#         [  6],
#         [  2],
#         [  4],
#         [  8],
#         [  4],
#         [  2],
#         [ 14],
#         [  3],
#         [  6],
#         [ 10],
#         [  3],
#         [  8],
#         [  3],
#         [  4],
#         [  7],
#         [  2],
#         [  3],
#         [  4],
#         [  6],
#         [  4],
#         [ 11],
#         [ 11],
#         [  1],
#         [ 10],
#         [  3],
#         [  5],
#         [  4],
#         [  5],
#         [  6],
#         [  2],
#         [  5],
#         [  6],
#         [  7],
#         [  4],
#         [  6],
#         [  0],
#         [  1],
#         [  1],
#         [  2],
#         [  3],
#         [  4],
#         [  4],
#         [  2],
#         [  2],
#         [  3],
#         [  2],
#         [  5],
#         [  4],
#         [  1],
#         [  2],
#         [  4],
#         [  1],
#         [ 22],
#         [ 14],
#         [  1],
#         [  1],
#         [  7],
#         [  3],
#         [  6],
#         [ 13],
#         [  3],
#         [ 12],
#         [  6],
#         [  6],
#         [  4],
#         [  2],
#         [  9],
#         [  3],
#         [ 10],
#         [  5],
#         [  7],
#         [  2],
#         [  5],
#         [  5],
#         [  3],
#         [  2],
#         [  4],
#         [  4],
#         [  5],
#         [  3],
#         [ 11],
#         [  2],
#         [  1],
#         [  4],
#         [  1],
#         [  2],
#         [  3],
#         [  6],
#         [  3],
#         [  3],
#         [  4],
#         [  5],
#         [  1],
#         [  5],
#         [  3],
#         [  2],
#         [  4],
#         [  1],
#         [  2],
#         [  7],
#         [  9],
#         [  2],
#         [  4],
#         [  4],
#         [  8],
#         [  2],
#         [  5],
#         [  5],
#         [  2],
#         [  5],
#         [  2],
#         [  3],
#         [  5],
#         [ 10],
#         [  6],
#         [  8],
#         [  5],
#         [  6],
#         [  3],
#         [  5],
#         [  2],
#         [  6],
#         [  2],
#         [  3],
#         [  0],
#         [  6],
#         [  7],
#         [  3],
#         [  2],
#         [  1],
#         [  2],
#         [  4],
#         [  7],
#         [  4],
#         [  3],
#         [  3],
#         [  5],
#         [  4],
#         [  2],
#         [  4],
#         [  4],
#         [  6],
#         [  2],
#         [  2],
#         [  4],
#         [  2],
#         [  2],
#         [  5],
#         [  4],
#         [  7],
#         [  4],
#         [  2],
#         [  3],
#         [  5],
#         [  4],
#         [  8],
#         [  1],
#         [  3],
#         [  4],
#         [  1],
#         [  3],
#         [  2],
#         [  2],
#         [  6],
#         [  6],
#         [  3],
#         [  3],
#         [  4],
#         [  4],
#         [  2],
#         [  1],
#         [  4],
#         [  8],
#         [  8],
#         [  5],
#         [  8],
#         [  9],
#         [  6],
#         [  6],
#         [  1],
#         [  5],
#         [  3],
#         [  2],
#         [  3],
#         [  8],
#         [  8],
#         [  2],
#         [  4],
#         [  6],
#         [  3],
#         [  5],
#         [  6],
#         [  2],
#         [  1],
#         [  3],
#         [  0],
#         [  3],
#         [  3],
#         [  5],
#         [  3],
#         [  9],
#         [  2],
#         [  5],
#         [  1],
#         [  4],
#         [  3],
#         [ 10],
#         [  6],
#         [  5],
#         [  4],
#         [  1],
#         [  4],
#         [  6],
#         [  0],
#         [  2],
#         [  3],
#         [  1],
#         [  3],
#         [  3],
#         [  7],
#         [  4],
#         [  1],
#         [  1],
#         [  8],
#         [  3],
#         [  5],
#         [  3],
#         [  6],
#         [  5],
#         [  1],
#         [ 14],
#         [  5],
#         [  1],
#         [  5],
#         [  3],
#         [  2],
#         [  3],
#         [  4],
#         [  1],
#         [  1],
#         [  2],
#         [  6],
#         [  2],
#         [  9],
#         [  1],
#         [  1],
#         [  1],
#         [  3],
#         [  4],
#         [  5],
#         [  1],
#         [ 12],
#         [ 10],
#         [  7],
#         [  6],
#         [  3],
#         [  2],
#         [  2],
#         [  4],
#         [  3],
#         [  3],
#         [  6],
#         [  5],
#         [  4],
#         [  1],
#         [  5],
#         [  8],
#         [ 11],
#         [  4],
#         [  4],
#         [  2],
#         [  1],
#         [  3],
#         [  5],
#         [  3],
#         [  1],
#         [  5],
#         [  7],
#         [  3],
#         [  6],
#         [  6],
#         [  3],
#         [  3],
#         [  5],
#         [  2],
#         [  2],
#         [  2],
#         [  2],
#         [  6],
#         [  5],
#         [  2],
#         [  2],
#         [ 11],
#         [  2],
#         [  7],
#         [  6],
#         [  3],
#         [  8],
#         [  1],
#         [  1],
#         [  2],
#         [  2],
#         [  1],
#         [ 12],
#         [  1],
#         [  5],
#         [  0],
#         [  0],
#         [  0],
#         [  2],
#         [  2],
#         [  3],
#         [  6],
#         [  4],
#         [  4],
#         [  5],
#         [  5],
#         [  3],
#         [  3],
#         [  2],
#         [  5],
#         [  3],
#         [  5],
#         [  1],
#         [  1],
#         [  0],
#         [  2],
#         [  3],
#         [  5],
#         [  2],
#         [  3],
#         [  5],
#         [  1],
#         [  3],
#         [  0],
#         [  2],
#         [  2],
#         [  2],
#         [  4],
#         [  2],
#         [  4],
#         [  3],
#         [  3],
#         [  2],
#         [  3],
#         [  4],
#         [  4],
#         [  2],
#         [  2],
#         [  7],
#         [  1],
#         [  2],
#         [  6],
#         [  5],
#         [  1],
#         [  3],
#         [  3],
#         [  1],
#         [  1],
#         [  2],
#         [  3],
#         [  3],
#         [  2],
#         [  4],
#         [  4],
#         [  5],
#         [  1],
#         [  2],
#         [  5],
#         [  4],
#         [  1],
#         [  4],
#         [  9],
#         [  4],
#         [ 12],
#         [  3],
#         [  2],
#         [  6],
#         [  4],
#         [  4],
#         [  3],
#         [  2],
#         [  2],
#         [  2],
#         [  4],
#         [  8],
#         [  3],
#         [  6],
#         [  2],
#         [  1],
#         [  2],
#         [ 12],
#         [  5],
#         [  4],
#         [  4],
#         [  1],
#         [  5],
#         [  1],
#         [  4],
#         [  4],
#         [  1],
#         [  5],
#         [  7],
#         [  7],
#         [  6],
#         [  5],
#         [  2],
#         [  1],
#         [  3],
#         [  5],
#         [  0],
#         [  4],
#         [  3],
#         [  4],
#         [  5],
#         [  2],
#         [  2],
#         [  6],
#         [  3],
#         [  2],
#         [  1],
#         [  1],
#         [  3],
#         [  5],
#         [  6],
#         [  3],
#         [  0],
#         [  1],
#         [  3],
#         [  6],
#         [  9],
#         [  2],
#         [  2],
#         [  4],
#         [ 12],
#         [ 13],
#         [  4],
#         [  2],
#         [  3],
#         [  9],
#         [  5],
#         [  2],
#         [  1],
#         [  6],
#         [  8],
#         [  7],
#         [  1],
#         [  0],
#         [  3],
#         [  3],
#         [ 10],
#         [  5],
#         [  2],
#         [  3],
#         [  2],
#         [  8],
#         [  7],
#         [ 15],
#         [  7],
#         [  9],
#         [  1],
#         [  7],
#         [  1],
#         [  4],
#         [  5],
#         [  2],
#         [  1],
#         [  7],
#         [  3],
#         [  8],
#         [ 11],
#         [  3],
#         [  2],
#         [  4],
#         [  8],
#         [221],
#         [  8],
#         [  3],
#         [  4],
#         [  3],
#         [  5],
#         [  2],
#         [  3],
#         [  4],
#         [  0],
#         [  4],
#         [  7],
#         [  3],
#         [  2],
#         [  7],
#         [  4],
#         [  6],
#         [  5],
#         [  3],
#         [  8],
#         [  3],
#         [  4],
#         [  4],
#         [  5],
#         [  4],
#         [  6],
#         [  2],
#         [  2],
#         [  5],
#         [  5],
#         [  7],
#         [  6],
#         [  3],
#         [  6],
#         [  5],
#         [  5],
#         [  4],
#         [  5],
#         [  5],
#         [  3],
#         [  5],
#         [  1],
#         [  3],
#         [  7],
#         [  6],
#         [  1],
#         [  6],
#         [  4],
#         [  1],
#         [ 11],
#         [  3],
#         [  2],
#         [  7],
#         [  5],
#         [  4],
#         [  4],
#         [ 11],
#         [  3],
#         [  3],
#         [  1],
#         [  1],
#         [  1],
#         [  2],
#         [  6],
#         [  5],
#         [  4],
#         [  4],
#         [  4],
#         [  3],
#         [  6],
#         [  6],
#         [  9],
#         [  3],
#         [  4],
#         [  5],
#         [  4],
#         [ 10],
#         [  5],
#         [  8],
#         [  2],
#         [  6],
#         [  3],
#         [  6],
#         [  1],
#         [  2],
#         [  4],
#         [  2],
#         [  4],
#         [  1],
#         [  5],
#         [  3],
#         [  2],
#         [  5],
#         [  1],
#         [  2],
#         [  4],
#         [  1],
#         [  4],
#         [  6],
#         [  1],
#         [  1],
#         [  5]], dtype=int64)

# %%
word_count = pd.DataFrame({
    '단어': cv.get_feature_names(),
    '빈도': tdm.sum(axis=0).flat
})

# %%
type(tdm.sum(axis=0))
# Out:
# numpy.matrix

# %%
word_count
# Out:
#              단어  빈도
# 0            10  29
# 1            20   3
# 2            90   6
# 3    absolutely   9
# 4         acted   3
# ..          ...  ..
# 495       wrong   3
# 496        year   5
# 497       years  14
# 498         yes   3
# 499       young   4
#
# [500 rows x 2 columns]

# %%
word_count.sort_values('빈도', ascending=False).head()
# Out:
#         단어   빈도
# 284  movie  182
# 153   film  163
# 33     bad   71
# 225   just   63
# 178   good   58

# %% [markdown]
# ### 단어 빈도 저장

# %%
word_count.to_csv('word_count.csv')

# %% [markdown]
# ## 단어 구름(wordcloud)

# %% [markdown]
# ### wordcloud 설치

# %%
#아나콘다를 이용할 경우:
# !conda install -y -c conda-forge wordcloud

#맥 또는 리눅스에서는 pip 명령어로 설치
# !pip install wordcloud
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\82102\anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-22.9.0-py39haa95532_0 --> conda-forge::conda-22.9.0-py39hcbf5309_1 None
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done
# Requirement already satisfied: wordcloud in c:\users\82102\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: pillow in c:\users\82102\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: matplotlib in c:\users\82102\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\82102\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\82102\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\82102\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\82102\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\82102\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\82102\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\82102\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\82102\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd

word_count = pd.read_csv('word_count.csv', index_col=0)
word_count.head()
# Out:
#            단어  빈도
# 0          10  29
# 1          20   3
# 2          90   6
# 3  absolutely   9
# 4       acted   3

# %% [markdown]
# ### 단어 구름

# %%
from wordcloud import WordCloud

#font_path: 글꼴의 경로
#max_words: 워드클라우드를 그릴 단어의 개수
#background_color: 배경색 설정
#width : 가로크기(픽셀 단위)
#height: 세로크기(픽셀 단위)
#배경은 흰색, 최대 100단어를 가로 400픽셀, 세로 300픽셀 크기로 단어 구름으로 그린다.
wc = WordCloud(background_color='white', max_words=100, width=400, height=300)

# %%
word_count.set_index('단어')
# Out:
#             빈도
# 단어
# 10          29
# 20           3
# 90           6
# absolutely   9
# acted        3
# ...         ..
# wrong        3
# year         5
# years       14
# yes          3
# young        4
#
# [500 rows x 1 columns]

# %%
word_count.set_index('단어')['빈도']
# Out:
# 단어
# 10            29
# 20             3
# 90             6
# absolutely     9
# acted          3
#               ..
# wrong          3
# year           5
# years         14
# yes            3
# young          4
# Name: 빈도, Length: 500, dtype: int64

# %%
# dictionary로 만드는 방법1
count_dic = word_count.set_index('단어')['빈도'].to_dict()

count_dic
# Out:
# {'10': 29,
#  '20': 3,
#  '90': 6,
#  'absolutely': 9,
#  'acted': 3,
#  'acting': 43,
#  'action': 7,
#  'actor': 10,
#  'actors': 19,
#  'actress': 3,
#  'actresses': 3,
#  'actually': 10,
#  'addition': 3,
#  'adorable': 4,
#  'aerial': 3,
#  'age': 4,
#  'amazing': 9,
#  'angel': 3,
#  'animation': 3,
#  'anne': 3,
#  'annoying': 6,
#  'appearance': 3,
#  'appreciate': 4,
#  'aren': 3,
#  'art': 13,
#  'attempt': 4,
#  'attention': 3,
#  'audience': 5,
#  'average': 3,
#  'avoid': 8,
#  'away': 5,
#  'awesome': 3,
#  'awful': 14,
#  'bad': 71,
#  'barely': 4,
#  'beautiful': 11,
#  'beginning': 4,
#  'believable': 6,
#  'believe': 8,
#  'best': 25,
#  'better': 18,
#  'big': 10,
#  'bit': 5,
#  'black': 10,
#  'book': 4,
#  'bore': 3,
#  'bored': 4,
#  'boring': 10,
#  'bought': 3,
#  'brilliance': 3,
#  'brilliant': 6,
#  'budget': 7,
#  'called': 3,
#  'came': 4,
#  'camera': 10,
#  'care': 5,
#  'cartoon': 3,
#  'cast': 18,
#  'casting': 6,
#  'certainly': 8,
#  'character': 24,
#  'characters': 35,
#  'charles': 4,
#  'charming': 3,
#  'cheap': 7,
#  'checking': 3,
#  'chemistry': 4,
#  'child': 5,
#  'cinema': 8,
#  'cinematography': 10,
#  'classic': 6,
#  'clever': 5,
#  'come': 5,
#  'comedy': 7,
#  'comes': 4,
#  'coming': 3,
#  'complete': 3,
#  'completely': 5,
#  'conclusion': 3,
#  'conflict': 3,
#  'consider': 4,
#  'convincing': 4,
#  'cool': 7,
#  'costs': 4,
#  'couldn': 5,
#  'course': 3,
#  'cover': 4,
#  'crap': 6,
#  'created': 4,
#  'credit': 3,
#  'cult': 5,
#  'dance': 4,
#  'dancing': 3,
#  'day': 5,
#  'death': 4,
#  'decent': 3,
#  'definitely': 9,
#  'delivers': 3,
#  'depth': 4,
#  'dialog': 3,
#  'dialogue': 13,
#  'did': 11,
#  'didn': 22,
#  'different': 5,
#  'directed': 3,
#  'directing': 9,
#  'direction': 5,
#  'director': 12,
#  'disappointed': 6,
#  'documentary': 3,
#  'does': 9,
#  'doesn': 12,
#  'don': 26,
#  'drago': 4,
#  'drama': 10,
#  'drive': 3,
#  'dvd': 3,
#  'earlier': 3,
#  'early': 3,
#  'easily': 4,
#  'easy': 4,
#  'ed': 3,
#  'editing': 6,
#  'effective': 3,
#  'effects': 9,
#  'end': 11,
#  'ending': 11,
#  'energy': 4,
#  'enjoy': 5,
#  'enjoyable': 3,
#  'enjoyed': 9,
#  'entertaining': 4,
#  'entire': 6,
#  'episode': 3,
#  'especially': 8,
#  'exactly': 3,
#  'example': 3,
#  'excellent': 16,
#  'expect': 4,
#  'experience': 7,
#  'extremely': 4,
#  'eyes': 4,
#  'face': 5,
#  'fact': 8,
#  'fails': 5,
#  'family': 7,
#  'fans': 5,
#  'far': 7,
#  'fast': 5,
#  'features': 3,
#  'feel': 3,
#  'feeling': 10,
#  'felt': 5,
#  'film': 163,
#  'films': 24,
#  'final': 3,
#  'finally': 3,
#  'fine': 5,
#  'flick': 6,
#  'follow': 4,
#  'fun': 5,
#  'funny': 19,
#  'fx': 3,
#  'game': 9,
#  'games': 3,
#  'garbage': 7,
#  'gave': 5,
#  'gem': 3,
#  'generally': 4,
#  'genuine': 3,
#  'gets': 6,
#  'giallo': 3,
#  'girl': 7,
#  'given': 3,
#  'gives': 6,
#  'glad': 4,
#  'god': 4,
#  'going': 10,
#  'good': 58,
#  'got': 8,
#  'grace': 3,
#  'graphics': 3,
#  'great': 41,
#  'greatest': 3,
#  'guess': 5,
#  'half': 6,
#  'happen': 3,
#  'happened': 3,
#  'hard': 4,
#  'haven': 3,
#  'having': 6,
#  'head': 3,
#  'heart': 3,
#  'highly': 10,
#  'hilarious': 6,
#  'hill': 3,
#  'history': 6,
#  'hitchcock': 6,
#  'holes': 6,
#  'hope': 4,
#  'horrible': 6,
#  'horror': 9,
#  'hour': 5,
#  'hours': 4,
#  'house': 3,
#  'huge': 4,
#  'human': 6,
#  'huston': 3,
#  'idea': 4,
#  'imagination': 4,
#  'important': 3,
#  'including': 3,
#  'incredible': 6,
#  'incredibly': 3,
#  'indulgent': 3,
#  'insult': 4,
#  'intelligence': 4,
#  'intelligent': 4,
#  'interesting': 12,
#  'involved': 5,
#  'james': 4,
#  'job': 9,
#  'john': 7,
#  'journey': 3,
#  'joy': 5,
#  'just': 63,
#  'kids': 8,
#  'kind': 8,
#  'knew': 3,
#  'know': 14,
#  'lacks': 6,
#  'lame': 5,
#  'laughable': 3,
#  'lead': 5,
#  'learn': 3,
#  'left': 3,
#  'let': 5,
#  'level': 4,
#  'life': 12,
#  'like': 48,
#  'liked': 10,
#  'line': 12,
#  'lines': 7,
#  'lion': 3,
#  'little': 17,
#  'living': 4,
#  'll': 7,
#  'location': 3,
#  'long': 8,
#  'look': 19,
#  'looked': 4,
#  'looking': 3,
#  'looks': 3,
#  'lost': 4,
#  'lot': 9,
#  'lots': 3,
#  'love': 22,
#  'loved': 10,
#  'lovely': 4,
#  'low': 5,
#  'main': 3,
#  'make': 22,
#  'makes': 8,
#  'making': 6,
#  'man': 13,
#  'martin': 3,
#  'massive': 3,
#  'master': 4,
#  'mature': 3,
#  'maybe': 4,
#  'mean': 4,
#  'meaning': 3,
#  'mediocre': 4,
#  'memorable': 6,
#  'memories': 3,
#  'mention': 5,
#  'mess': 8,
#  'mickey': 4,
#  'mind': 5,
#  'minute': 4,
#  'minutes': 8,
#  'miyazaki': 3,
#  'moment': 3,
#  'money': 6,
#  'movie': 182,
#  'movies': 29,
#  'moving': 4,
#  'music': 14,
#  'narrative': 3,
#  'negative': 3,
#  'new': 5,
#  'nice': 6,
#  'night': 5,
#  'non': 5,
#  'nonsense': 3,
#  'note': 3,
#  'obviously': 3,
#  'occasionally': 4,
#  'oh': 5,
#  'old': 8,
#  'original': 4,
#  'oscar': 3,
#  'overall': 5,
#  'paced': 3,
#  'particularly': 5,
#  'parts': 4,
#  'pathetic': 5,
#  'people': 14,
#  'perfect': 6,
#  'performance': 12,
#  'performances': 6,
#  'period': 5,
#  'pg': 4,
#  'piece': 10,
#  'place': 4,
#  'plain': 4,
#  'play': 9,
#  'played': 10,
#  'playing': 7,
#  'plot': 28,
#  'point': 4,
#  'poor': 6,
#  'portrayal': 6,
#  'possible': 3,
#  'possibly': 3,
#  'predictable': 10,
#  'premise': 4,
#  'presents': 3,
#  'pretentious': 4,
#  'pretty': 13,
#  'probably': 8,
#  'problems': 4,
#  'produced': 3,
#  'production': 5,
#  'provoking': 3,
#  'puppets': 3,
#  'pure': 3,
#  'quality': 3,
#  'quite': 10,
#  'race': 3,
#  'racial': 3,
#  'ranks': 3,
#  'rate': 3,
#  'rating': 4,
#  'ray': 4,
#  'real': 21,
#  'really': 41,
#  'recommend': 13,
#  'recommended': 6,
#  'released': 3,
#  'remake': 3,
#  'remember': 3,
#  'rent': 6,
#  'rest': 4,
#  'ridiculous': 5,
#  'right': 13,
#  'role': 4,
#  'roles': 4,
#  'ruthless': 3,
#  'said': 5,
#  'saw': 12,
#  'say': 13,
#  'scale': 3,
#  'scamp': 4,
#  'scene': 14,
#  'scenes': 19,
#  'score': 3,
#  'screen': 14,
#  'screenwriter': 3,
#  'script': 24,
#  'sea': 3,
#  'second': 6,
#  'seeing': 7,
#  'seen': 23,
#  'self': 7,
#  'sense': 3,
#  'series': 8,
#  'seriously': 3,
#  'set': 3,
#  'sets': 4,
#  'short': 11,
#  'shot': 5,
#  'silent': 5,
#  'simply': 10,
#  'single': 5,
#  'slow': 6,
#  'small': 4,
#  'solid': 5,
#  'song': 4,
#  'songs': 4,
#  'sound': 6,
#  'soundtrack': 4,
#  'south': 3,
#  'space': 3,
#  'speak': 3,
#  'special': 9,
#  'spent': 3,
#  'spoilers': 3,
#  'stage': 3,
#  'stanwyck': 3,
#  'star': 4,
#  'stars': 3,
#  'started': 5,
#  'stereotypes': 3,
#  'stories': 4,
#  'story': 28,
#  'storyline': 4,
#  'strong': 5,
#  'stunning': 3,
#  'stupid': 14,
#  'style': 6,
#  'sub': 3,
#  'subtle': 7,
#  'sucked': 7,
#  'sucks': 8,
#  'super': 3,
#  'superb': 5,
#  'sure': 3,
#  'surprisingly': 3,
#  'suspense': 8,
#  'tale': 4,
#  'talented': 3,
#  'talk': 5,
#  'tell': 4,
#  'terrible': 12,
#  'terrific': 5,
#  'theater': 4,
#  'theme': 3,
#  'thing': 13,
#  'things': 12,
#  'think': 21,
#  'thinking': 3,
#  'thoroughly': 3,
#  'thought': 12,
#  'thriller': 5,
#  'thrown': 3,
#  'time': 43,
#  'times': 5,
#  'today': 4,
#  'told': 3,
#  'tom': 5,
#  'torture': 4,
#  'totally': 15,
#  'touching': 3,
#  'trash': 4,
#  'trilogy': 3,
#  'true': 4,
#  'truly': 9,
#  'try': 4,
#  'trying': 4,
#  'turn': 3,
#  'tv': 8,
#  'type': 3,
#  'unbelievable': 4,
#  'unconvincing': 3,
#  'understand': 9,
#  'unfortunately': 4,
#  'ups': 4,
#  'use': 6,
#  'used': 8,
#  'usual': 4,
#  'utterly': 4,
#  'values': 3,
#  've': 13,
#  'visual': 4,
#  'want': 6,
#  'war': 3,
#  'wasn': 7,
#  'waste': 14,
#  'wasted': 7,
#  'watch': 17,
#  'watchable': 3,
#  'watched': 9,
#  'watching': 22,
#  'way': 23,
#  'white': 8,
#  'wilkinson': 3,
#  'wind': 3,
#  'wish': 3,
#  'women': 3,
#  'won': 5,
#  'wonderful': 18,
#  'wonderfully': 3,
#  'word': 5,
#  'work': 20,
#  'works': 5,
#  'world': 6,
#  'worse': 11,
#  'worst': 11,
#  'worth': 13,
#  'wouldn': 3,
#  'write': 3,
#  'writer': 3,
#  'writing': 13,
#  'written': 7,
#  'wrong': 3,
#  'year': 5,
#  'years': 14,
#  'yes': 3,
#  'young': 4}

# %%
# dictionary로 만드는 방법2
dict(zip(word_count['단어'], word_count['빈도']))
# Out:
# {'10': 29,
#  '20': 3,
#  '90': 6,
#  'absolutely': 9,
#  'acted': 3,
#  'acting': 43,
#  'action': 7,
#  'actor': 10,
#  'actors': 19,
#  'actress': 3,
#  'actresses': 3,
#  'actually': 10,
#  'addition': 3,
#  'adorable': 4,
#  'aerial': 3,
#  'age': 4,
#  'amazing': 9,
#  'angel': 3,
#  'animation': 3,
#  'anne': 3,
#  'annoying': 6,
#  'appearance': 3,
#  'appreciate': 4,
#  'aren': 3,
#  'art': 13,
#  'attempt': 4,
#  'attention': 3,
#  'audience': 5,
#  'average': 3,
#  'avoid': 8,
#  'away': 5,
#  'awesome': 3,
#  'awful': 14,
#  'bad': 71,
#  'barely': 4,
#  'beautiful': 11,
#  'beginning': 4,
#  'believable': 6,
#  'believe': 8,
#  'best': 25,
#  'better': 18,
#  'big': 10,
#  'bit': 5,
#  'black': 10,
#  'book': 4,
#  'bore': 3,
#  'bored': 4,
#  'boring': 10,
#  'bought': 3,
#  'brilliance': 3,
#  'brilliant': 6,
#  'budget': 7,
#  'called': 3,
#  'came': 4,
#  'camera': 10,
#  'care': 5,
#  'cartoon': 3,
#  'cast': 18,
#  'casting': 6,
#  'certainly': 8,
#  'character': 24,
#  'characters': 35,
#  'charles': 4,
#  'charming': 3,
#  'cheap': 7,
#  'checking': 3,
#  'chemistry': 4,
#  'child': 5,
#  'cinema': 8,
#  'cinematography': 10,
#  'classic': 6,
#  'clever': 5,
#  'come': 5,
#  'comedy': 7,
#  'comes': 4,
#  'coming': 3,
#  'complete': 3,
#  'completely': 5,
#  'conclusion': 3,
#  'conflict': 3,
#  'consider': 4,
#  'convincing': 4,
#  'cool': 7,
#  'costs': 4,
#  'couldn': 5,
#  'course': 3,
#  'cover': 4,
#  'crap': 6,
#  'created': 4,
#  'credit': 3,
#  'cult': 5,
#  'dance': 4,
#  'dancing': 3,
#  'day': 5,
#  'death': 4,
#  'decent': 3,
#  'definitely': 9,
#  'delivers': 3,
#  'depth': 4,
#  'dialog': 3,
#  'dialogue': 13,
#  'did': 11,
#  'didn': 22,
#  'different': 5,
#  'directed': 3,
#  'directing': 9,
#  'direction': 5,
#  'director': 12,
#  'disappointed': 6,
#  'documentary': 3,
#  'does': 9,
#  'doesn': 12,
#  'don': 26,
#  'drago': 4,
#  'drama': 10,
#  'drive': 3,
#  'dvd': 3,
#  'earlier': 3,
#  'early': 3,
#  'easily': 4,
#  'easy': 4,
#  'ed': 3,
#  'editing': 6,
#  'effective': 3,
#  'effects': 9,
#  'end': 11,
#  'ending': 11,
#  'energy': 4,
#  'enjoy': 5,
#  'enjoyable': 3,
#  'enjoyed': 9,
#  'entertaining': 4,
#  'entire': 6,
#  'episode': 3,
#  'especially': 8,
#  'exactly': 3,
#  'example': 3,
#  'excellent': 16,
#  'expect': 4,
#  'experience': 7,
#  'extremely': 4,
#  'eyes': 4,
#  'face': 5,
#  'fact': 8,
#  'fails': 5,
#  'family': 7,
#  'fans': 5,
#  'far': 7,
#  'fast': 5,
#  'features': 3,
#  'feel': 3,
#  'feeling': 10,
#  'felt': 5,
#  'film': 163,
#  'films': 24,
#  'final': 3,
#  'finally': 3,
#  'fine': 5,
#  'flick': 6,
#  'follow': 4,
#  'fun': 5,
#  'funny': 19,
#  'fx': 3,
#  'game': 9,
#  'games': 3,
#  'garbage': 7,
#  'gave': 5,
#  'gem': 3,
#  'generally': 4,
#  'genuine': 3,
#  'gets': 6,
#  'giallo': 3,
#  'girl': 7,
#  'given': 3,
#  'gives': 6,
#  'glad': 4,
#  'god': 4,
#  'going': 10,
#  'good': 58,
#  'got': 8,
#  'grace': 3,
#  'graphics': 3,
#  'great': 41,
#  'greatest': 3,
#  'guess': 5,
#  'half': 6,
#  'happen': 3,
#  'happened': 3,
#  'hard': 4,
#  'haven': 3,
#  'having': 6,
#  'head': 3,
#  'heart': 3,
#  'highly': 10,
#  'hilarious': 6,
#  'hill': 3,
#  'history': 6,
#  'hitchcock': 6,
#  'holes': 6,
#  'hope': 4,
#  'horrible': 6,
#  'horror': 9,
#  'hour': 5,
#  'hours': 4,
#  'house': 3,
#  'huge': 4,
#  'human': 6,
#  'huston': 3,
#  'idea': 4,
#  'imagination': 4,
#  'important': 3,
#  'including': 3,
#  'incredible': 6,
#  'incredibly': 3,
#  'indulgent': 3,
#  'insult': 4,
#  'intelligence': 4,
#  'intelligent': 4,
#  'interesting': 12,
#  'involved': 5,
#  'james': 4,
#  'job': 9,
#  'john': 7,
#  'journey': 3,
#  'joy': 5,
#  'just': 63,
#  'kids': 8,
#  'kind': 8,
#  'knew': 3,
#  'know': 14,
#  'lacks': 6,
#  'lame': 5,
#  'laughable': 3,
#  'lead': 5,
#  'learn': 3,
#  'left': 3,
#  'let': 5,
#  'level': 4,
#  'life': 12,
#  'like': 48,
#  'liked': 10,
#  'line': 12,
#  'lines': 7,
#  'lion': 3,
#  'little': 17,
#  'living': 4,
#  'll': 7,
#  'location': 3,
#  'long': 8,
#  'look': 19,
#  'looked': 4,
#  'looking': 3,
#  'looks': 3,
#  'lost': 4,
#  'lot': 9,
#  'lots': 3,
#  'love': 22,
#  'loved': 10,
#  'lovely': 4,
#  'low': 5,
#  'main': 3,
#  'make': 22,
#  'makes': 8,
#  'making': 6,
#  'man': 13,
#  'martin': 3,
#  'massive': 3,
#  'master': 4,
#  'mature': 3,
#  'maybe': 4,
#  'mean': 4,
#  'meaning': 3,
#  'mediocre': 4,
#  'memorable': 6,
#  'memories': 3,
#  'mention': 5,
#  'mess': 8,
#  'mickey': 4,
#  'mind': 5,
#  'minute': 4,
#  'minutes': 8,
#  'miyazaki': 3,
#  'moment': 3,
#  'money': 6,
#  'movie': 182,
#  'movies': 29,
#  'moving': 4,
#  'music': 14,
#  'narrative': 3,
#  'negative': 3,
#  'new': 5,
#  'nice': 6,
#  'night': 5,
#  'non': 5,
#  'nonsense': 3,
#  'note': 3,
#  'obviously': 3,
#  'occasionally': 4,
#  'oh': 5,
#  'old': 8,
#  'original': 4,
#  'oscar': 3,
#  'overall': 5,
#  'paced': 3,
#  'particularly': 5,
#  'parts': 4,
#  'pathetic': 5,
#  'people': 14,
#  'perfect': 6,
#  'performance': 12,
#  'performances': 6,
#  'period': 5,
#  'pg': 4,
#  'piece': 10,
#  'place': 4,
#  'plain': 4,
#  'play': 9,
#  'played': 10,
#  'playing': 7,
#  'plot': 28,
#  'point': 4,
#  'poor': 6,
#  'portrayal': 6,
#  'possible': 3,
#  'possibly': 3,
#  'predictable': 10,
#  'premise': 4,
#  'presents': 3,
#  'pretentious': 4,
#  'pretty': 13,
#  'probably': 8,
#  'problems': 4,
#  'produced': 3,
#  'production': 5,
#  'provoking': 3,
#  'puppets': 3,
#  'pure': 3,
#  'quality': 3,
#  'quite': 10,
#  'race': 3,
#  'racial': 3,
#  'ranks': 3,
#  'rate': 3,
#  'rating': 4,
#  'ray': 4,
#  'real': 21,
#  'really': 41,
#  'recommend': 13,
#  'recommended': 6,
#  'released': 3,
#  'remake': 3,
#  'remember': 3,
#  'rent': 6,
#  'rest': 4,
#  'ridiculous': 5,
#  'right': 13,
#  'role': 4,
#  'roles': 4,
#  'ruthless': 3,
#  'said': 5,
#  'saw': 12,
#  'say': 13,
#  'scale': 3,
#  'scamp': 4,
#  'scene': 14,
#  'scenes': 19,
#  'score': 3,
#  'screen': 14,
#  'screenwriter': 3,
#  'script': 24,
#  'sea': 3,
#  'second': 6,
#  'seeing': 7,
#  'seen': 23,
#  'self': 7,
#  'sense': 3,
#  'series': 8,
#  'seriously': 3,
#  'set': 3,
#  'sets': 4,
#  'short': 11,
#  'shot': 5,
#  'silent': 5,
#  'simply': 10,
#  'single': 5,
#  'slow': 6,
#  'small': 4,
#  'solid': 5,
#  'song': 4,
#  'songs': 4,
#  'sound': 6,
#  'soundtrack': 4,
#  'south': 3,
#  'space': 3,
#  'speak': 3,
#  'special': 9,
#  'spent': 3,
#  'spoilers': 3,
#  'stage': 3,
#  'stanwyck': 3,
#  'star': 4,
#  'stars': 3,
#  'started': 5,
#  'stereotypes': 3,
#  'stories': 4,
#  'story': 28,
#  'storyline': 4,
#  'strong': 5,
#  'stunning': 3,
#  'stupid': 14,
#  'style': 6,
#  'sub': 3,
#  'subtle': 7,
#  'sucked': 7,
#  'sucks': 8,
#  'super': 3,
#  'superb': 5,
#  'sure': 3,
#  'surprisingly': 3,
#  'suspense': 8,
#  'tale': 4,
#  'talented': 3,
#  'talk': 5,
#  'tell': 4,
#  'terrible': 12,
#  'terrific': 5,
#  'theater': 4,
#  'theme': 3,
#  'thing': 13,
#  'things': 12,
#  'think': 21,
#  'thinking': 3,
#  'thoroughly': 3,
#  'thought': 12,
#  'thriller': 5,
#  'thrown': 3,
#  'time': 43,
#  'times': 5,
#  'today': 4,
#  'told': 3,
#  'tom': 5,
#  'torture': 4,
#  'totally': 15,
#  'touching': 3,
#  'trash': 4,
#  'trilogy': 3,
#  'true': 4,
#  'truly': 9,
#  'try': 4,
#  'trying': 4,
#  'turn': 3,
#  'tv': 8,
#  'type': 3,
#  'unbelievable': 4,
#  'unconvincing': 3,
#  'understand': 9,
#  'unfortunately': 4,
#  'ups': 4,
#  'use': 6,
#  'used': 8,
#  'usual': 4,
#  'utterly': 4,
#  'values': 3,
#  've': 13,
#  'visual': 4,
#  'want': 6,
#  'war': 3,
#  'wasn': 7,
#  'waste': 14,
#  'wasted': 7,
#  'watch': 17,
#  'watchable': 3,
#  'watched': 9,
#  'watching': 22,
#  'way': 23,
#  'white': 8,
#  'wilkinson': 3,
#  'wind': 3,
#  'wish': 3,
#  'women': 3,
#  'won': 5,
#  'wonderful': 18,
#  'wonderfully': 3,
#  'word': 5,
#  'work': 20,
#  'works': 5,
#  'world': 6,
#  'worse': 11,
#  'worst': 11,
#  'worth': 13,
#  'wouldn': 3,
#  'write': 3,
#  'writer': 3,
#  'writing': 13,
#  'written': 7,
#  'wrong': 3,
#  'year': 5,
#  'years': 14,
#  'yes': 3,
#  'young': 4}

# %%
cloud = wc.fit_words(count_dic)

# %%
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x17A8CAB9940>

# %%
cloud.to_file('cloud.png')

# %%
import os

os.getcwd()
# Out:
# 'D:\\SWTHINKING\\개인\\NCS\\자연어처리_160\\05. 인공지능 자연어처리 이론및실습\\기본\\강의\\src'

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd

df = pd.read_excel('imdb.xlsx', index_col=0)
df.head()
# Out:
#                                               review  sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=500, stop_words='english')

# %%
tdm = tfidf.fit_transform(df['review'])
tdm
# Out:
# <748x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3434 stored elements in Compressed Sparse Row format>

# %%
print(tdm)
# Out:
#   (0, 264)	0.43676152065842583
#   (0, 499)	0.5112421488050499
#   (0, 284)	0.23148088751652843
#   (0, 286)	0.5112421488050499
#   (0, 385)	0.48261672511123166
#   (1, 185)	0.4508252485652821
#   (1, 27)	0.4630757536620436
#   (1, 61)	0.330043211383874
#   (1, 253)	0.4775650258680224
#   (1, 417)	0.4952984618525245
#   (2, 293)	0.3326996842333155
#   (2, 242)	0.30667834544717537
#   (2, 319)	0.24142314513946203
#   (2, 321)	0.3140711939059074
#   (2, 5)	0.22041303500891976
#   (2, 354)	0.32260561111952785
#   (2, 108)	0.3140711939059074
#   (2, 54)	0.2890474338764623
#   (2, 71)	0.32260561111952785
#   (2, 475)	0.30015739096222105
#   (2, 43)	0.2943241984036562
#   (2, 284)	0.15064019733663225
#   (3, 394)	0.6747516922530598
#   (3, 287)	0.5316526285937699
#   (3, 244)	0.5119137000618044
#   :	:
#   (739, 146)	1.0
#   (740, 9)	0.83021432552157
#   (740, 182)	0.5574443234070687
#   (741, 250)	0.6167137686897145
#   (741, 481)	0.4797072301038725
#   (741, 405)	0.4694360111750707
#   (741, 239)	0.41130880407139175
#   (742, 284)	1.0
#   (743, 46)	0.5981049664516606
#   (743, 179)	0.5396026349269978
#   (743, 473)	0.46523248115164195
#   (743, 225)	0.36695801390238936
#   (744, 456)	0.4787210520194807
#   (744, 369)	0.3723703953368651
#   (744, 484)	0.3723703953368651
#   (744, 333)	0.46419670610274333
#   (744, 153)	0.22103009773200633
#   (744, 253)	0.4787210520194807
#   (745, 483)	1.0
#   (746, 33)	1.0
#   (747, 215)	0.4648939655177951
#   (747, 216)	0.4648939655177951
#   (747, 205)	0.4648939655177951
#   (747, 283)	0.4507891319381984
#   (747, 468)	0.3852401342043983

# %%
word_count = pd.DataFrame({
    '단어': tfidf.get_feature_names(),
    'tf-idf': tdm.sum(axis=0).flat
})

word_count.sort_values('tf-idf', ascending=False).head(5)
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#         단어     tf-idf
# 284  movie  44.917213
# 153   film  40.356390
# 33     bad  25.258572
# 225   just  20.296871
# 178   good  18.604656

# %% [markdown]
# ## 기존 TDM에서 변환

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=500, stop_words='english')
tdm2 = cv.fit_transform(df['review'])

# %%
from sklearn.feature_extraction.text import  TfidfTransformer

trans = TfidfTransformer()
tdm3 = trans.fit_transform(tdm2)
tdm3
# Out:
# <748x500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3434 stored elements in Compressed Sparse Row format>

# %%
# tf-idf 두 방법 비교
import numpy as np

np.allclose(tdm.A, tdm3.A)
# Out:
# True

# %%
wc2 = pd.DataFrame({
    '단어': cv.get_feature_names(),
    'tf-idf': tdm3.sum(axis=0).flat
})

wc2.sort_values('tf-idf', ascending=False).head()
# Out:
# C:\Users\82102\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#         단어     tf-idf
# 284  movie  44.917213
# 153   film  40.356390
# 33     bad  25.258572
# 225   just  20.296871
# 178   good  18.604656

# %% [markdown]
# ##  영어품사 태깅 & 표제어 추출

# %%
# !conda install -y -c conda-forge spacy 설치
# !pip install -U spacy

# %%
# !python -m spacy download en_core_web_sm

# %%
import spacy

# 영어 모형 불러오기
nlp = spacy.load("en_core_web_sm")

# 모형에 영어 텍스트 적용
text = "Wikipedia is maintained by volunteers."
doc = nlp(text)

# %%
for token in doc:
    print(token.text, 
          token.lemma_,  # 표제어
          token.pos_,    # 단어의 품사
          token.tag_,    # 자세한 품사
          token.dep_,    # 문법적 의존 관계
          token.is_stop) # 불용어 여부
# Out:
# Wikipedia Wikipedia PROPN NNP nsubjpass False
# is be AUX VBZ auxpass True
# maintained maintain VERB VBN ROOT False
# by by ADP IN agent True
# volunteers volunteer NOUN NNS pobj False
# . . PUNCT . punct False

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
# 명사와 동사의 표제어로 단어 문서 행렬 만들기
def extract_nv(text):
    doc = nlp(text)
    words = []
    for token in doc:
        print(token.tag_)
        if token.tag_[0] in 'NV':
            words.append(token.lemma_.lower())
    return words

# %%
extract_nv('Apple is a company')
