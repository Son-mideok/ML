# %%
import os
import re

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
DATA_IN_PATH = './data_in/'
TRAIN_CLEAN_DATA = 'train_clean.csv'

RANDOM_SEED = 42
TEST_SPLIT = 0.2

# %%
train_data = pd.read_csv(DATA_IN_PATH + TRAIN_CLEAN_DATA)

# %%
reviews = list(train_data['review'])
sentiments = list(train_data['sentiment'])

# %%
sentences = []
for review in reviews:
    sentences.append(review.split())

# %%
num_features = 300 # 단어 임베딩 벡터 차원
min_word_count = 40 # 적은 빈도수 배제용
num_workers = 4     # 학습 위한 프로세스 개수 지정
context = 10        # 컨텍스트 윈도우 크기 지정
downsampling = 1e-3 # 빠른 학습을 위해 정답 단어 레이블 다운샘플링
                    # 비율 지정(보통 0.001이 좋은 성능을 낸다고 함)

# %%
import logging
# level=logging.INFO : word2vec 학습 과정에서 로그 메시지를 양식에 맞게 -
# - info 수준으로 보여줌 
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', \
                   level=logging.INFO)

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec(sentences, workers=num_workers, \
           vector_size=num_features, min_count = min_word_count, \
            window = context, sample = downsampling)
# Out:
# 2022-11-07 16:53:24,592 : INFO : collecting all words and their counts
# 2022-11-07 16:53:24,593 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-11-07 16:53:24,799 : INFO : PROGRESS: at sentence #10000, processed 1261831 words, keeping 152318 word types
# 2022-11-07 16:53:25,016 : INFO : PROGRESS: at sentence #20000, processed 2510155 words, keeping 237994 word types
# 2022-11-07 16:53:25,131 : INFO : collected 275098 word types from a corpus of 3129782 raw words and 25000 sentences
# 2022-11-07 16:53:25,131 : INFO : Creating a fresh vocabulary
# 2022-11-07 16:53:25,229 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=40 retains 8869 unique words (3.2239420133915915%% of original 275098, drops 266229)', 'datetime': '2022-11-07T16:53:25.229417', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-11-07 16:53:25,230 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=40 leaves 2364402 word corpus (75.54526161886035%% of original 3129782, drops 765380)', 'datetime': '2022-11-07T16:53:25.230417', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-11-07 16:53:25,266 : INFO : deleting the raw counts dictionary of 275098 items
# 2022-11-07 16:53:25,270 : INFO : sample=0.001 downsamples 25 most-common words
# 2022-11-07 16:53:25,271 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2267885.849206524 word corpus (95.9%% of prior 2364402)', 'datetime': '2022-11-07T16:53:25.271439', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'prepare_vocab'}
# 2022-11-07 16:53:25,335 : INFO : estimated required memory for 8869 words and 300 dimensions: 25720100 bytes
# 2022-11-07 16:53:25,335 : INFO : resetting layer weights
# 2022-11-07 16:53:25,345 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-11-07T16:53:25.345924', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'build_vocab'}
# 2022-11-07 16:53:25,346 : INFO : Word2Vec lifecycle event {'msg': 'training model with 4 workers on 8869 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2022-11-07T16:53:25.346924', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2022-11-07 16:53:26,355 : INFO : EPOCH 1 - PROGRESS: at 70.14% examples, 1590535 words/s, in_qsize 7, out_qsize 0
# 2022-11-07 16:53:26,756 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-11-07 16:53:26,759 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-11-07 16:53:26,772 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-11-07 16:53:26,773 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-11-07 16:53:26,773 : INFO : EPOCH - 1 : training on 3129782 raw words (2267891 effective words) took 1.4s, 1592425 effective words/s
# 2022-11-07 16:53:27,777 : INFO : EPOCH 2 - PROGRESS: at 67.34% examples, 1533826 words/s, in_qsize 7, out_qsize 0
# 2022-11-07 16:53:28,241 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-11-07 16:53:28,245 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-11-07 16:53:28,247 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-11-07 16:53:28,253 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-11-07 16:53:28,253 : INFO : EPOCH - 2 : training on 3129782 raw words (2268045 effective words) took 1.5s, 1534605 effective words/s
# 2022-11-07 16:53:29,267 : INFO : EPOCH 3 - PROGRESS: at 63.19% examples, 1424729 words/s, in_qsize 7, out_qsize 0
# 2022-11-07 16:53:29,818 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-11-07 16:53:29,820 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-11-07 16:53:29,836 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-11-07 16:53:29,837 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-11-07 16:53:29,837 : INFO : EPOCH - 3 : training on 3129782 raw words (2267942 effective words) took 1.6s, 1433916 effective words/s
# 2022-11-07 16:53:30,844 : INFO : EPOCH 4 - PROGRESS: at 63.19% examples, 1434706 words/s, in_qsize 7, out_qsize 0
# 2022-11-07 16:53:31,397 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-11-07 16:53:31,398 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-11-07 16:53:31,413 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-11-07 16:53:31,414 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-11-07 16:53:31,414 : INFO : EPOCH - 4 : training on 3129782 raw words (2267667 effective words) took 1.6s, 1439743 effective words/s
# 2022-11-07 16:53:32,417 : INFO : EPOCH 5 - PROGRESS: at 60.61% examples, 1383366 words/s, in_qsize 7, out_qsize 0
# 2022-11-07 16:53:33,005 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2022-11-07 16:53:33,015 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-11-07 16:53:33,023 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-11-07 16:53:33,025 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-11-07 16:53:33,025 : INFO : EPOCH - 5 : training on 3129782 raw words (2267546 effective words) took 1.6s, 1409827 effective words/s
# 2022-11-07 16:53:33,025 : INFO : Word2Vec lifecycle event {'msg': 'training on 15648910 raw words (11339091 effective words) took 7.7s, 1476780 effective words/s', 'datetime': '2022-11-07T16:53:33.025574', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'train'}
# 2022-11-07 16:53:33,026 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=8869, vector_size=300, alpha=0.025)', 'datetime': '2022-11-07T16:53:33.026575', 'gensim': '4.1.2', 'python': '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'created'}

# %%
model.wv.index_to_key
# Out:
# ['movie',
#  'film',
#  'one',
#  'like',
#  'would',
#  'even',
#  'good',
#  'really',
#  'see',
#  '-',
#  'get',
#  'much',
#  'story',
#  'also',
#  'time',
#  'first',
#  'great',
#  'people',
#  'could',
#  'make',
#  'made',
#  'bad',
#  'think',
#  'many',
#  'never',
#  'two',
#  'little',
#  'way',
#  'well',
#  'watch',
#  'best',
#  'know',
#  'seen',
#  'love',
#  'characters',
#  'character',
#  'movies',
#  'ever',
#  'still',
#  'it.',
#  'movie.',
#  'films',
#  'plot',
#  'acting',
#  'show',
#  '"i',
#  'go',
#  'better',
#  'say',
#  'something',
#  'makes',
#  'film.',
#  'watching',
#  'back',
#  'scene',
#  'film,',
#  'real',
#  'find',
#  'new',
#  'movie,',
#  "i'm",
#  'actually',
#  'scenes',
#  'every',
#  'life',
#  'man',
#  'going',
#  'nothing',
#  'look',
#  'quite',
#  'another',
#  'lot',
#  'old',
#  '"this',
#  'want',
#  'end',
#  'pretty',
#  'thing',
#  'seems',
#  'got',
#  '&',
#  "can't",
#  'take',
#  'years',
#  'part',
#  'give',
#  'actors',
#  'young',
#  'may',
#  'us',
#  "that's",
#  'without',
#  'things',
#  'gets',
#  'though',
#  'big',
#  'around',
#  'thought',
#  'almost',
#  'it,',
#  'director',
#  'always',
#  'saw',
#  "i've",
#  'must',
#  'come',
#  'work',
#  'whole',
#  'cast',
#  'horror',
#  'might',
#  "he's",
#  "there's",
#  'bit',
#  'least',
#  'enough',
#  'probably',
#  'feel',
#  'last',
#  'original',
#  '\\"the',
#  'since',
#  'rather',
#  'long',
#  'far',
#  'fact',
#  'kind',
#  'world',
#  'funny',
#  'found',
#  'anything',
#  'comes',
#  'worst',
#  'making',
#  'trying',
#  'action',
#  'however,',
#  'right',
#  'interesting',
#  'done',
#  'point',
#  'believe',
#  'looks',
#  'guy',
#  'goes',
#  'put',
#  'family',
#  'played',
#  'main',
#  'series',
#  'hard',
#  'anyone',
#  'role',
#  'especially',
#  'music',
#  'worth',
#  'yet',
#  'seem',
#  'plays',
#  'performance',
#  'takes',
#  'script',
#  'looking',
#  'watched',
#  'sure',
#  'minutes',
#  'someone',
#  'different',
#  'tv',
#  'woman',
#  'set',
#  'away',
#  'three',
#  'times',
#  'shows',
#  'maybe',
#  'comedy',
#  'girl',
#  'although',
#  'left',
#  'everything',
#  'seeing',
#  'simply',
#  'john',
#  'american',
#  'fun',
#  'special',
#  'completely',
#  'play',
#  'true',
#  'everyone',
#  'reason',
#  'read',
#  'used',
#  'need',
#  'nice',
#  'given',
#  'use',
#  'beautiful',
#  'high',
#  'time.',
#  'sense',
#  'truly',
#  'place',
#  'idea',
#  '--',
#  'help',
#  'version',
#  'rest',
#  'try',
#  'less',
#  'well,',
#  'black',
#  'money',
#  'came',
#  'job',
#  'dvd',
#  'second',
#  'ending',
#  'recommend',
#  'excellent',
#  'tell',
#  'getting',
#  'shot',
#  'keep',
#  'instead',
#  'actor',
#  '(and',
#  'gives',
#  '"the',
#  'said',
#  'full',
#  'half',
#  'enjoy',
#  'couple',
#  'day',
#  'poor',
#  'let',
#  'playing',
#  'definitely',
#  'supposed',
#  'audience',
#  'early',
#  'become',
#  'felt',
#  'along',
#  'effects',
#  'understand',
#  'all,',
#  'small',
#  'remember',
#  'later',
#  'book',
#  'entire',
#  'together',
#  'liked',
#  'absolutely',
#  'wife',
#  'fan',
#  'next',
#  'went',
#  'star',
#  'start',
#  'year',
#  'often',
#  'hollywood',
#  'screen',
#  'certainly',
#  '(the',
#  'perhaps',
#  'several',
#  'time,',
#  '2',
#  'sort',
#  'waste',
#  'night',
#  'human',
#  'is,',
#  'becomes',
#  'short',
#  'wonderful',
#  'seemed',
#  'kids',
#  'men',
#  'loved',
#  '\x96',
#  'piece',
#  'war',
#  'classic',
#  'father',
#  'production',
#  'house',
#  'home',
#  'wanted',
#  'else',
#  'camera',
#  'hope',
#  'women',
#  'that,',
#  'totally',
#  '.',
#  'live',
#  'course',
#  'performances',
#  'top',
#  'lost',
#  'tries',
#  'based',
#  'line',
#  'mind',
#  'video',
#  '10',
#  'final',
#  "i'd",
#  'able',
#  'called',
#  'wants',
#  'perfect',
#  'friends',
#  'gave',
#  "they're",
#  'death',
#  'already',
#  'story,',
#  'enjoyed',
#  'finally',
#  'person',
#  'name',
#  'either',
#  'turn',
#  'sex',
#  'turns',
#  'them.',
#  'care',
#  'starts',
#  'dead',
#  'episode',
#  'problem',
#  'despite',
#  'written',
#  'low',
#  'school',
#  'stupid',
#  'mean',
#  'face',
#  'behind',
#  'moments',
#  'lead',
#  'this,',
#  'favorite',
#  'and,',
#  'lines',
#  'sound',
#  'head',
#  'white',
#  'him.',
#  'guess',
#  'took',
#  'michael',
#  'cannot',
#  'stars',
#  'fine',
#  'budget',
#  'title',
#  'me,',
#  'kill',
#  'highly',
#  'extremely',
#  'terrible',
#  'others',
#  'dialogue',
#  "film's",
#  'evil',
#  'lack',
#  'beginning',
#  'me.',
#  'sometimes',
#  'throughout',
#  'style',
#  'heard',
#  'obviously',
#  'story.',
#  'boring',
#  'feeling',
#  'dark',
#  'lives',
#  'fans',
#  'good.',
#  'works',
#  'decent',
#  'expect',
#  'this.',
#  'soon',
#  'good,',
#  'killer',
#  'boy',
#  'mr.',
#  'particularly',
#  'well.',
#  'attempt',
#  'looked',
#  'late',
#  'case',
#  'course,',
#  'friend',
#  'directed',
#  'fight',
#  'amazing',
#  'wrong',
#  'quality',
#  'leave',
#  'mother',
#  'picture',
#  'one.',
#  'entertaining',
#  'save',
#  'thinking',
#  'complete',
#  'life.',
#  'close',
#  'viewer',
#  'exactly',
#  'taken',
#  'guys',
#  'writing',
#  'awful',
#  'finds',
#  'run',
#  'whose',
#  'all.',
#  'wonder',
#  'except',
#  'somewhat',
#  'living',
#  'number',
#  'across',
#  'strong',
#  'police',
#  'told',
#  'says',
#  'movies,',
#  'worse',
#  'parts',
#  'shown',
#  'obvious',
#  'laugh',
#  'opening',
#  '3',
#  'coming',
#  'james',
#  'car',
#  'films,',
#  'past',
#  'running',
#  'direction',
#  'type',
#  'wish',
#  'usually',
#  'group',
#  'huge',
#  'side',
#  'acting,',
#  'supporting',
#  'major',
#  'taking',
#  'children',
#  'girls',
#  'stop',
#  'act',
#  'hour',
#  'turned',
#  'tells',
#  'none',
#  'known',
#  'started',
#  'local',
#  'knew',
#  'killed',
#  'due',
#  'here,',
#  'stories',
#  'town',
#  'single',
#  'game',
#  ',',
#  'happens',
#  'female',
#  'bring',
#  'including',
#  'again,',
#  'call',
#  'way,',
#  'cinema',
#  'son',
#  'clearly',
#  'movies.',
#  'british',
#  'fact,',
#  'mostly',
#  'actress',
#  'brilliant',
#  'humor',
#  'talking',
#  'hit',
#  'art',
#  'voice',
#  'involved',
#  'characters,',
#  'one,',
#  'giving',
#  'musical',
#  'child',
#  'whether',
#  'bad.',
#  'history',
#  'order',
#  'ends',
#  'end,',
#  'david',
#  'falls',
#  'saying',
#  'drama',
#  'heart',
#  'robert',
#  'matter',
#  'bad,',
#  "i'll",
#  'easily',
#  'however',
#  'serious',
#  'relationship',
#  'eyes',
#  'nearly',
#  'modern',
#  'chance',
#  'horrible',
#  'feels',
#  'needs',
#  'kid',
#  'actual',
#  'beyond',
#  'here.',
#  'cut',
#  'appears',
#  'similar',
#  'important',
#  'moment',
#  'example',
#  'change',
#  'comic',
#  'that.',
#  'five',
#  'simple',
#  'upon',
#  'strange',
#  'knows',
#  'using',
#  'yes,',
#  'happened',
#  'named',
#  'within',
#  'four',
#  'but,',
#  'among',
#  '!',
#  'usual',
#  'released',
#  'english',
#  'lots',
#  'mention',
#  'stuff',
#  'basically',
#  'slow',
#  'bunch',
#  'romantic',
#  'kept',
#  'interest',
#  'certain',
#  'typical',
#  'near',
#  'city',
#  'hours',
#  'showing',
#  '(i',
#  'plot,',
#  'overall',
#  'brought',
#  'fall',
#  'blood',
#  'days',
#  'her.',
#  'murder',
#  'tried',
#  'body',
#  'song',
#  'miss',
#  'out.',
#  'him,',
#  'middle',
#  'greatest',
#  'end.',
#  'life,',
#  'apparently',
#  'events',
#  'score',
#  'jack',
#  'way.',
#  'happy',
#  'sad',
#  'stay',
#  'shots',
#  'george',
#  'cheap',
#  'is.',
#  'working',
#  'add',
#  'talk',
#  'decided',
#  'seen.',
#  '(as',
#  'age',
#  'begins',
#  'buy',
#  'surprised',
#  'hear',
#  'brother',
#  'so,',
#  'again.',
#  'french',
#  'alone',
#  'became',
#  'famous',
#  'hate',
#  'daughter',
#  'learn',
#  'annoying',
#  'happen',
#  '(which',
#  'paul',
#  'films.',
#  'sit',
#  'songs',
#  '"a',
#  'richard',
#  'jokes',
#  'de',
#  'easy',
#  'please',
#  "what's",
#  'sets',
#  'it."',
#  'light',
#  'experience',
#  'view',
#  'on.',
#  'documentary',
#  'cinematography',
#  'ten',
#  'also,',
#  'hell',
#  'funny,',
#  'possibly',
#  "who's",
#  'attention',
#  'sexual',
#  'sequence',
#  'peter',
#  'straight',
#  'king',
#  '1',
#  'stand',
#  'hand',
#  'meets',
#  'gore',
#  'power',
#  'word',
#  'episodes',
#  'difficult',
#  'husband',
#  'clear',
#  'elements',
#  'leaves',
#  'keeps',
#  'realize',
#  'means',
#  'god',
#  'violence',
#  'ones',
#  'poorly',
#  'television',
#  'genre',
#  'roles',
#  'character,',
#  'japanese',
#  'red',
#  'flick',
#  'somehow',
#  'out,',
#  'cool',
#  'figure',
#  'reality',
#  'funny.',
#  'characters.',
#  'them,',
#  'eventually',
#  'silly',
#  'towards',
#  'move',
#  'possible',
#  'rent',
#  'brings',
#  'doubt',
#  'theme',
#  '5',
#  'killing',
#  'reading',
#  'lady',
#  'scary',
#  'on,',
#  'moving',
#  'filmed',
#  'emotional',
#  'room',
#  'previous',
#  'leads',
#  'unfortunately',
#  'problems',
#  'third',
#  '(or',
#  'say,',
#  'deal',
#  'oscar',
#  'though,',
#  'tom',
#  'novel',
#  'review',
#  'talent',
#  'rock',
#  'too.',
#  'comments',
#  'hero',
#  'leading',
#  'message',
#  'imagine',
#  'write',
#  'level',
#  'forget',
#  'incredibly',
#  'career',
#  'enjoyable',
#  'check',
#  'various',
#  'ridiculous',
#  'plenty',
#  'meant',
#  'animation',
#  'personal',
#  'needed',
#  'avoid',
#  'writer',
#  'oh',
#  'feature',
#  'future',
#  'create',
#  'meet',
#  'gone',
#  'total',
#  'hardly',
#  'begin',
#  'country',
#  'theater',
#  'team',
#  'manages',
#  'forced',
#  'form',
#  'particular',
#  '4',
#  'fairly',
#  'appear',
#  'points',
#  'hilarious',
#  'viewers',
#  'interested',
#  'fast',
#  'follow',
#  'effort',
#  'fantastic',
#  'now,',
#  'tale',
#  'dramatic',
#  'weak',
#  'older',
#  'expecting',
#  'male',
#  'zombie',
#  'unfortunately,',
#  'unless',
#  'her,',
#  'general',
#  'political',
#  'words',
#  'attempts',
#  'scenes,',
#  'sounds',
#  'joe',
#  'reviews',
#  'average',
#  'subject',
#  'features',
#  'york',
#  'mystery',
#  '(a',
#  'show.',
#  'class',
#  'pay',
#  'up,',
#  'scene,',
#  'lee',
#  'then,',
#  'crap',
#  'whatever',
#  'work.',
#  'worked',
#  'dance',
#  'decides',
#  'premise',
#  'plain',
#  'up.',
#  'minute',
#  'disney',
#  'dialog',
#  'badly',
#  'ask',
#  'expected',
#  '20',
#  'there.',
#  'wait',
#  'social',
#  'forward',
#  'uses',
#  'open',
#  '(who',
#  'man,',
#  'better.',
#  'viewing',
#  'storyline',
#  'front',
#  'deep',
#  'writers',
#  'there,',
#  'directors',
#  'crime',
#  'comment',
#  'waiting',
#  'fails',
#  'nature',
#  'slightly',
#  'hold',
#  'admit',
#  'soundtrack',
#  'watch.',
#  'deserves',
#  'unique',
#  'sees',
#  'stage',
#  'pure',
#  'battle',
#  'portrayed',
#  'parents',
#  'sequences',
#  'telling',
#  'footage',
#  'times,',
#  "let's",
#  'dull',
#  'compared',
#  'season',
#  'sister',
#  'spent',
#  'eye',
#  'biggest',
#  'atmosphere',
#  'realistic',
#  'rating',
#  "'the",
#  'movie."',
#  'talented',
#  'visual',
#  'outside',
#  'predictable',
#  'weird',
#  'agree',
#  'considering',
#  'dr.',
#  'recent',
#  'perfectly',
#  'earth',
#  'unlike',
#  'caught',
#  'quickly',
#  'show,',
#  'spend',
#  'inside',
#  'large',
#  'memorable',
#  'people,',
#  'powerful',
#  'entirely',
#  'fighting',
#  'editing',
#  'space',
#  'ways',
#  'william',
#  'kills',
#  "we're",
#  'bill',
#  'sequel',
#  'casting',
#  'lame',
#  'wrote',
#  'rich',
#  'result',
#  'amount',
#  'etc.',
#  'return',
#  'filled',
#  'free',
#  'question',
#  'ben',
#  'period',
#  'consider',
#  'sorry',
#  'screenplay',
#  'earlier',
#  'work,',
#  'sci-fi',
#  'secret',
#  'disappointed',
#  'former',
#  'gay',
#  'actors,',
#  'neither',
#  'release',
#  'filmmakers',
#  'said,',
#  'showed',
#  'material',
#  'appreciate',
#  'cheesy',
#  'popular',
#  'superb',
#  'entertainment',
#  'runs',
#  'odd',
#  'missing',
#  'comedy,',
#  'copy',
#  'moves',
#  'seriously',
#  'married',
#  'creepy',
#  'hot',
#  'following',
#  'suddenly',
#  'positive',
#  'people.',
#  'plot.',
#  'present',
#  'decide',
#  '(in',
#  'imdb',
#  'basic',
#  'shame',
#  'box',
#  'animated',
#  'years.',
#  'portrayal',
#  'plus',
#  'considered',
#  'recently',
#  'thriller',
#  'break',
#  'common',
#  'hands',
#  'credits',
#  'too,',
#  'beauty',
#  'ideas',
#  'you.',
#  'crazy',
#  'barely',
#  'mark',
#  'leaving',
#  'wasted',
#  'fantasy',
#  'western',
#  'missed',
#  '...',
#  'scenes.',
#  'italian',
#  ...]

# %%
'''
words : 단어의 모음인 하나의 리뷰
model : word2vec모델
num_features : word2vec로 임베딩할 때 정했던 벡터의 차원 수
'''
def get_features(words, model, num_features):
    # 출력 벡터 초기화
    feature_vector = np.zeros((num_features),dtype=np.float32)
    num_words = 0
    # 어휘 사전 준비
    index_to_key_set = set(model.wv.index_to_key)
    for w in words:
        if w in index_to_key_set:
            num_words += 1
            # 사전에 해당하는 단어에 대해 단어 벡터를 더함
            feature_vector = np.add(feature_vector, model.wv[w])
    feature_vector = np.divide(feature_vector, num_words)
    return feature_vector

# %%
def get_dataset(reviews, model, num_features):
    dataset = list()
    for s in reviews:
        dataset.append(get_features(s, model, num_features))
    reviewFeatureVecs = np.stack(dataset)
    print(dataset)
    print("------------")
    print(reviewFeatureVecs)
    return reviewFeatureVecs

# %%
test_data_vecs = get_dataset(sentences[:1], model, num_features)
# Out:
# [array([-8.82773697e-02,  2.17417136e-01, -2.59579830e-02,  7.32667670e-02,
#        -2.66081616e-02, -1.97184503e-01, -8.88579339e-02,  1.01570457e-01,
#        -1.34318173e-01, -1.71068937e-01, -4.68272902e-02, -9.62430090e-02,
#        -7.96676129e-02, -3.98080200e-02,  2.81828456e-02, -1.81281924e-01,
#         1.41212195e-01, -1.10254712e-01, -1.18992127e-01, -1.17746003e-01,
#        -4.84001637e-02, -1.81146991e-02,  2.16895565e-01,  1.69422999e-02,
#         1.63398981e-01, -1.32727429e-01, -3.87945145e-01, -6.05251193e-02,
#        -5.07661179e-02, -9.18957964e-02,  1.76544562e-01, -1.63193360e-01,
#         9.65613723e-02, -8.78242105e-02, -8.45573470e-02, -9.41260234e-02,
#        -5.30423075e-02, -5.73751442e-02,  1.96397826e-02, -2.60585807e-02,
#        -1.30722120e-01, -6.66299090e-02,  7.61836544e-02, -6.61454275e-02,
#         3.68529744e-02,  7.01156706e-02,  1.62113711e-01,  4.52426895e-02,
#         1.78937480e-01,  1.88850969e-01,  1.74959809e-01, -3.80175449e-02,
#        -1.05224028e-01,  3.38169128e-01, -1.62965968e-01,  1.73107997e-01,
#         5.02046607e-02, -5.63982539e-02, -6.35708570e-02,  3.15646641e-02,
#         5.28677367e-02,  1.50781095e-01,  8.59453157e-02,  1.39143109e-01,
#        -1.52235299e-01,  1.25377208e-01,  2.17811778e-01,  9.45566297e-02,
#        -1.68126583e-01, -7.25288317e-02, -4.16041166e-02,  8.48668739e-02,
#         9.56252813e-02, -2.22692266e-01, -3.75215560e-02, -1.53163791e-01,
#        -7.47088939e-02,  1.23814112e-02,  3.79010700e-02,  8.09751451e-02,
#        -1.63140938e-01,  2.46254727e-02, -5.16338721e-02,  3.66424233e-01,
#         7.39129186e-02, -5.96707650e-02, -8.22386891e-02,  4.36885580e-02,
#         3.99106413e-01,  1.71827868e-01,  1.37474433e-01, -8.91750827e-02,
#         8.86215121e-02,  1.61761060e-01,  2.89005876e-01,  2.03010291e-01,
#         2.71748495e-03,  9.84580070e-03,  1.92219019e-02, -5.91850914e-02,
#        -5.91630712e-02,  8.78721550e-02,  1.01639539e-01,  1.91401020e-01,
#         3.15915719e-02, -4.35443223e-02, -4.35538962e-03,  8.00157562e-02,
#        -2.61477716e-02, -3.79788061e-03, -1.90888435e-01, -4.37762327e-02,
#         2.40721434e-01,  5.40772872e-03, -5.69361523e-02, -1.76985875e-01,
#         4.68366407e-02,  2.65207898e-04, -3.61950211e-02, -2.75843710e-01,
#        -8.09443668e-02,  1.40411422e-01,  9.05268937e-02,  1.54083857e-04,
#         1.33351862e-01,  1.26486450e-01, -1.85304061e-01, -1.13171890e-01,
#         2.10474759e-01,  1.87746391e-01, -1.11061931e-01,  2.16967359e-01,
#         6.27602339e-02, -2.65674919e-01,  6.65774196e-02,  5.62843420e-02,
